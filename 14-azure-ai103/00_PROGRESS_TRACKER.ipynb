# %% [markdown]
# # 00. Concept Progress Tracker — Chapter 14 (Azure AI-103)
#
# One root-level checklist for **every concept notebook in this chapter**. You don't have to study in order — open any concept, anywhere in sections `01_responses_api_basics/` … `08_document_intelligence_capstone/`, run it, and the next time you run this tracker it is detected and marked ✅ automatically.
#
# **How it works** (all logic lives in [`progress_tracker.py`](progress_tracker.py)):
#
# - **Live scan** — every run re-discovers the concept notebooks on disk (including any added later); nothing is a hardcoded list.
# - **Auto-detection** — a concept counts as *visited* when its notebook has at least one executed code cell (execution counts / saved outputs). Save the notebook after running it so the execution state is on disk.
# - **Persistent** — detections are written to `concept_progress.json` next to this notebook, so a concept stays marked even if you later clear its outputs. Delete that file to reset all progress.
# - **Manual override** — studied a concept from its `.py` script instead of the notebook? Mark it by hand with `mark_done("<any unique path substring>")`.

# %% [markdown]
# ## Refresh & show the checklist
#
# Run this cell any time — it re-scans all sections, absorbs newly executed notebooks into `concept_progress.json`, and renders the per-section checklist with progress bars. Every concept name links straight to its notebook.

# %%
from progress_tracker import refresh, show

refresh()
show()
# Out:
# ## Chapter 14 concept progress — 25/55 (45%)
#
# ### 01_responses_api_basics — 6/6  `████████████████████`
# - ✅ [01_responses_api_basics/note/01_first_api_call.ipynb](01_responses_api_basics/note/01_first_api_call.ipynb) *(marked auto 2026-08-08)*
# - ✅ [01_responses_api_basics/note/02_model_behaviour.ipynb](01_responses_api_basics/note/02_model_behaviour.ipynb) *(marked auto 2026-08-08)*
# - ✅ [01_responses_api_basics/note/03_reasoning.ipynb](01_responses_api_basics/note/03_reasoning.ipynb) *(marked auto 2026-08-08)*
# - ✅ [01_responses_api_basics/note/04_multi_modal.ipynb](01_responses_api_basics/note/04_multi_modal.ipynb) *(marked auto 2026-08-08)*
# - ✅ [01_responses_api_basics/note/05_web_search.ipynb](01_responses_api_basics/note/05_web_search.ipynb) *(marked auto 2026-08-08)*
# - ✅ [01_responses_api_basics/note/06_code_interpreter.ipynb](01_responses_api_basics/note/06_code_interpreter.ipynb) *(marked auto 2026-08-08)*
#
# ...

# %% [markdown]
# ## Manual marking
#
# For concepts you studied without executing the notebook (e.g. server-side files like the Function App notebooks, or a concept you ran as a plain `python script.py`). The pattern is any unique substring of the notebook path shown in the checklist above — you'll be told if it's ambiguous.

# %%
from progress_tracker import mark_done, mark_undone

# Examples — uncomment and edit:
# mark_done("05_web_search")                 # mark one concept done
# mark_done("03-cloudxeus-mcp")              # works with folder names too
# mark_undone("05_web_search")               # unmark it again

# %% [markdown]
# ## Resetting
#
# - **One concept:** `mark_undone("<pattern>")` above.
# - **Everything:** delete [`concept_progress.json`](concept_progress.json) and re-run the refresh cell — auto-detection will immediately re-mark any notebook that still has executed cells on disk (clear a notebook's outputs *and* delete the JSON entry to fully reset it).
#
# `concept_progress.json` is your personal progress and is git-ignored — it won't show up in commits or collide with anyone else's progress.
