# %% [markdown]
# # 05. Grounding Answers With the Built-in Web Search Tool
#
# This notebook (**AI-103 -> Section 01**) attaches the Responses API's built-in `web_search` tool to a request, letting the model ground its answer in live web results (with citations) instead of relying solely on its static training data.
#
# **Difficulty: Intermediate**

# %% [markdown]
# ## Prerequisites
#
# **Python packages** (already in this repo's root `requirements.txt`):
# - `openai`, `azure-identity`, `python-dotenv` (the latter used by the centralized `azure_config.py` module)
#
# **Azure resources**
# - An Azure OpenAI / AI Foundry deployment with the built-in `web_search` tool available. Availability of built-in tools can depend on the model/region/deployment configuration -- check your Foundry project if you get a tool-not-supported error.
# - Entra ID auth via `az login`.
#
# **Environment variables** -- add to the root `.env`:
# ```
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.services.ai.azure.com/openai/v1
# AZURE_OPENAI_DEPLOYMENT=gpt-4.1
# ```
# > These are read centrally via `14-azure-ai103/azure_config.py` (`from azure_config import config` -- see `config.openai_endpoint` and `config.openai_deployment`) instead of a per-notebook `load_dotenv()` + `os.getenv(...)`.

# %% [markdown]
# ## What You'll Learn
# - Built-in, server-side Responses API tools vs. custom function tools
# - The `tool_choice` parameter (`auto`, `required`, `none`, or naming a specific tool)
# - Live web grounding vs. relying on a model's static training knowledge
# - When to reach for web search vs. your own private-document grounding (RAG)

# %% [markdown]
# ### 1. Imports and configuration

# %%
import sys
from pathlib import Path

from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from openai import OpenAI

_start = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
for _parent in [_start, *_start.parents]:
    if (_parent / "azure_config.py").exists():
        sys.path.insert(0, str(_parent))
        break

from azure_config import config

endpoint = config.openai_endpoint
deployment_name = config.openai_deployment2
token_provider = config.openai_api_key
#token_provider = get_bearer_token_provider(DefaultAzureCredential(), "https://ai.azure.com/.default")

# %% [markdown]
# ### 2. Build the client

# %%
client = OpenAI(
    base_url=endpoint,
    api_key=token_provider,
)

# %% [markdown]
# ### 3. Send a request with the `web_search` tool attached
#
# `tools=[{"type": "web_search"}]` attaches the built-in web search tool; `tool_choice="auto"` lets the model itself decide whether the question actually needs a web lookup or can be answered directly.
#
# **Exam tip:** Distinguish two tool categories in the Responses API: **built-in/hosted tools** (`web_search`, `code_interpreter`, `file_search`) which the service executes entirely server-side and returns results for in the same response; and **custom function tools**, where the model only returns a proposed function name + arguments and *your application code* must execute it and send the result back in a follow-up call. AI-102 scenario questions often hinge on this "who actually executes the tool" distinction. `tool_choice` accepts `"auto"` (model decides), `"required"` (must call some tool), `"none"` (never call a tool), or an object naming one specific tool to force.
#
# **Alternatives:** When the answer must come from your own private/proprietary documents rather than the public internet, ground the model in your own knowledge base instead -- via the `file_search` built-in tool, or an Azure AI Search-backed RAG agent like the one referenced in `03_conversations_and_evaluation/01_conversation.py`.

# %%
response = client.responses.create(
    model=deployment_name,
    instructions="You are a helpful research assistant. Always cite your sources.",
    input="What are the latest developments in AI regulation in the European Union?",
    tools=[{"type": "web_search"}],
    tool_choice="auto",
)

# %% [markdown]
# ### 4. Read the answer

# %%
print(f"answer: {response.output_text}")
# Out:
# answer: Here are the key *latest* developments in EU AI regulation as of late July 2026, with an emphasis on what has changed recently and what actually applies when.
#
# ---
#
# ## 1. The EU AI Act is in force, with staggered dates
#
# The core law is the **EU AI Act – Regulation (EU) 2024/1689**, the world’s first comprehensive AI law, published in the Official Journal on 12 July 2024 and in force since 1 August 2024. It applies a **risk‑based framework** (prohibited, high‑risk, limited, minimal) and sets fines up to €35M or 7% of global turnover. ([euaiactchecklist.com](https://euaiactchecklist.com/eu-ai-act-complete-guide.html))
#
# Key parts already active (pre‑2026 developments, but important context):
#
# - **Prohibited AI practices** (e.g. certain manipulative or social scoring systems) became enforceable on **2 February 2025**. ([decodethefuture.org](https://decodethefuture.org/en/eu-ai-act-explained/))
# - Initial rules for **general‑purpose AI (GPAI) / foundation models** started applying from **2 August 2025** (documentation, model governance, etc.). ([decodethefuture.org](https://decodethefuture.org/en/eu-ai-act-explained/))
#
# ---
#
# ## 2. The 2026 “Digital Omnibus on AI” – first major amendment package
#
# The most recent big change is the **Digital Omnibus on AI**, formally **Regulation (EU) 2026/1744**, adopted on **8 July 2026** and published in the Official Journal on **24 July 2026**. ([eur-lex.europa.eu](https://eur-lex.europa.eu/eli/reg/2026/1744/oj/eng))
#
# This regulation **amends** the AI Act and several other digital laws to:
# - **Simplify implementation** of harmonised AI rules.
# - Adjust the **enforcement timeline**, especially for high‑risk systems.
# - Align AI obligations with sectoral legislation (e.g. product safety, aviation, machinery). ([eur-lex.europa.eu](https://eur-lex.europa.eu/eli/reg/2026/1744/oj/eng))
#
# Politically, the “Digital Omnibus” deal was reached on **7 May 2026**, then approved by the Council on **29 June 2026**, and is now formally in force after publication. ([axis-intelligence.com](https://axis-intelligence.com/eu-ai-act-news/))
#
# ---
#
# ## 3. What changed: enforcement timeline and high‑risk AI deadlines
#
# Before the Omnibus, **2 August 2026** was widely understood as the moment “full enforcement” would kick in for high‑risk AI. That is **no longer correct**.
#
# ### High‑risk Annex III systems (e.g., credit scoring, recruitment, essential services)
#
# The Omnibus **pushes back the core deadlines** for stand‑alone Annex III high‑risk systems:
#
# - Many high‑risk obligations that were supposed to apply in August 2026 now have a **later deadline**.
# - For example, some analyses note that organizations deploying Annex III standalone high‑risk systems now have until **December 2, 2027** to achieve full compliance, giving a 16‑month extension compared with the original schedule. ([lumenova.ai](https://www.lumenova.ai/blog/eu-ai-act-delays-july-2026/))
#
# Reason: the EU recognized that **technical standards and conformity assessment mechanisms weren’t ready**, so penalizing companies against non‑existent standards was legally incoherent. The Omnibus is described by commentators as a **“sequencing correction,” not a retreat from regulation**. ([axis-intelligence.com](https://axis-intelligence.com/eu-ai-act-news/))
#
# Bottom line:
# - High‑risk deadlines are **spread out into 2027+** rather than clustering in August 2026.
# - High‑risk is also **more narrowly scoped** in some areas, to avoid over‑inclusion of lower‑risk use cases. ([lumenova.ai](https://www.lumenova.ai/blog/eu-ai-act-delays-july-2026/))
#
# ---
#
# ## 4. What still happens on 2 August 2026
#
# Even after the Omnibus, **2 August 2026** remains a **major enforcement date**, but the focus is different:
#
# 1. **GPAI / foundation models – penalty enforcement**
#    - The European Commission and national authorities gain **full penalty enforcement powers** over providers of GPAI models as of 2 August 2026.
#    - GPAI obligations (e.g. model documentation, training data summaries, safety and cybersecurity measures) are already in force; August 2026 is when **sanctions and market surveillance powers fully bite.** ([axis-intelligence.com](https://axis-intelligence.com/eu-ai-act-news/))
#
# 2. **Article 50 transparency obligations**
#    - **Article 50** of the AI Act (transparency for AI systems used to interact with natural persons, emotion recognition, etc.) becomes broadly enforceable on **2 August 2026**.
#    - Many commentators describe this as an **“August 2026 transparency trap”** because these obligations apply to a wide range of non‑high‑risk AI deployments, and are not delayed by the Omnibus. ([lumenova.ai](https://www.lumenova.ai/blog/eu-ai-act-delays-july-2026/))
#
# 3. **Full investigation and sanction powers for market surveillance authorities**
#    - National authorities gain more expansive powers to **inspect, investigate, and sanction** AI Act breaches starting 2 August 2026, even though some high‑risk obligations are deferred. ([axis-intelligence.com](https://axis-intelligence.com/eu-ai-act-news/))
#
# In short: **August 2026 is still a hard enforcement date**, just not the “everything high‑risk goes live” date that older guidance suggested.
#
# ---
#
# ## 5. Current compliance landscape (mid‑2026)
#
# Recent guidance aimed at businesses highlights:
#
# - The AI Act now has a **two‑speed implementation**:
#   - **Already enforceable:** prohibitions, some GPAI rules, certain obligations for limited‑risk systems.
#   - **Deferred but coming:** full high‑risk regime with conformity assessments and CE‑marking into 2027 and beyond. ([legalnodes.com](https://www.legalnodes.com/article/eu-ai-act-2026-updates-compliance-requirements-and-business-risks))
#
# - Enterprises are being warned that:
#   - Many are **behind** on preparations for the August 2026 transparency and GPAI enforcement dates. ([nextwavesinsight.com](https://nextwavesinsight.com/eu-ai-act-enforcement-enterprise-compliance-2026/))
#   - Fines under Article 99 (up to €35M or 7% of global turnover) are very real, especially for systematic non‑compliance. ([decodethefuture.org](https://decodethefuture.org/en/eu-ai-act-explained/))
#
# Several recent briefings in 2026 focus on:
#
# - Mapping AI systems against the new, **post‑Omnibus timeline** and re‑prioritizing which systems to bring into compliance first. ([axis-intelligence.com](https://axis-intelligence.com/eu-ai-act-enforcement-guide/))
# - Integrating AI Act obligations with other EU digital rules (Digital Services Act, Data Act, product safety law, etc.). ([bloomberg.com](https://www.bloomberg.com/professional/insights/regulation/july-2026-global-regulatory-brief-stablecoins-ai-governance-and-regulatory-sandboxes/))
#
# ---
#
# ## 6. How this affects organizations outside the EU (e.g., US‑based)
#
# For a US‑based company:
#
# - The AI Act applies **extraterritorially** to any provider or deployer placing AI systems on the **EU market** or using them in the EU (even if headquartered abroad). ([euaiactchecklist.com](https://euaiactchecklist.com/eu-ai-act-complete-guide.html))
# - GPAI providers serving EU clients need to be ready for **Article 50 transparency** and **GPAI enforcement** in August 2026, even if their infrastructure is outside the EU. ([axis-intelligence.com](https://axis-intelligence.com/eu-ai-act-news/))
# - High‑risk system obligations are delayed, but **not optional**; the extra time is meant for building compliance, not avoiding it. ([lumenova.ai](https://www.lumenova.ai/blog/eu-ai-act-delays-july-2026/))
#
# ---
#
# ## Summary
#
# Latest developments in EU AI regulation:
#
# - The **EU AI Act (Reg. 2024/1689)** is in force with a risk‑based structure and significant penalties.
# - The **Digital Omnibus on AI (Reg. 2026/1744)**, adopted July 2026, is the first major amendment, simplifying implementation and **pushing back high‑risk deadlines** into 2027 while preserving core protections.
# - **2 August 2026** remains a **critical date**, primarily for:
#   - Full enforcement and sanctions against **GPAI providers**, and
#   - Activation of broad **Article 50 transparency obligations** and strengthened market surveillance powers.
# - Enterprises now face a **revised, longer runway for high‑risk systems**, but an **imminent enforcement cliff** for general‑purpose and many “limited‑risk” AI uses.
#
# If you’d like, I can break this down into a simple timeline or a checklist for what a US company should do before 2 August 2026.

# %% [markdown]
# ## Summary
#
# You attached the built-in `web_search` tool and let the model decide (`tool_choice="auto"`) whether to use it, producing an answer grounded in current web results rather than only the model's training data.

# %% [markdown]
# ## Try It Yourself
# 1. **Easy:** Change the question to a different current-events topic.
# 2. **Medium:** Set `tool_choice="none"` and compare the output -- expect it to fall back to the model's static training knowledge, likely with a knowledge-cutoff caveat and no citations.
# 3. **Advanced:** Inspect `response.output` for the web-search tool-call item (similar to the `code_interpreter_call` item inspected in the next notebook) and print the specific sources it used, rather than relying on the model mentioning them in prose.
