# %% [markdown]
# # Libraries for Neural Networks - Pybrain 2

# %%
# !pip3 install https://github.com/pybrain/pybrain/archive/0.3.3.zip
# Out:
# Collecting https://github.com/pybrain/pybrain/archive/0.3.3.zip
#   Using cached 0.3.3.zip
#   Installing build dependencies ... -
# \
# done
#   Getting requirements to build wheel ... -
# done
#   Preparing metadata (pyproject.toml) ... -
# done
# Requirement already satisfied: scipy in /Users/soubhik/AI/full-stack-ai-with-python/venv/lib/python3.11/site-packages (from PyBrain==0.3.1) (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /Users/soubhik/AI/full-stack-ai-with-python/venv/lib/python3.11/site-packages (from scipy->PyBrain==0.3.1) (2.3.5)

# %%
import pybrain

# %%
from pybrain.tools.shortcuts import buildNetwork
from pybrain.datasets import SupervisedDataSet
from pybrain.supervised import BackpropTrainer
from pybrain.structure.modules import SigmoidLayer

# %%
network = buildNetwork(2, 3, 1, outclass = SigmoidLayer, hiddenclass = SigmoidLayer, bias = False)

# %%
network
# Out:
# <FeedForwardNetwork 'FeedForwardNetwork-5'>

# %%
network['in']
# Out:
# <LinearLayer 'in'>

# %%
network['hidden0']
# Out:
# <SigmoidLayer 'hidden0'>

# %%
network['out']
# Out:
# <SigmoidLayer 'out'>

# %%
network['bias']

# %%
dataset = SupervisedDataSet(2, 1)
dataset.addSample((0,0), (0,))
dataset.addSample((0,1), (1,))
dataset.addSample((1,0), (1,))
dataset.addSample((1,1), (0,))

# %%
dataset['input']
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]])

# %%
dataset['target']
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        [0.]])

# %%
optimizer = BackpropTrainer(module=network, dataset=dataset, learningrate=0.5)

# %%
epochs = 30000
error = []
for epoch in range(epochs):
  error_average = optimizer.train()
  if epoch % 1000 == 0:
    print('Epoch: ' + str(epoch + 1) + ' Error: ' + str(error_average))
    error.append(error_average)
# Out:
# Epoch: 1 Error: 0.12993931119919616
# Epoch: 1001 Error: 0.07604378596555592
# Epoch: 2001 Error: 0.03789618606532982
# Epoch: 3001 Error: 0.03397666857980382
# Epoch: 4001 Error: 0.03292557418328805
# Epoch: 5001 Error: 0.032449045333322164
# Epoch: 6001 Error: 0.03217936576002616
# Epoch: 7001 Error: 0.03200660954898109
# Epoch: 8001 Error: 0.031886787337762575
# Epoch: 9001 Error: 0.031798945302840775
# Epoch: 10001 Error: 0.03173186225242393
# Epoch: 11001 Error: 0.03167899836678459
# Epoch: 12001 Error: 0.03163628978040469
# Epoch: 13001 Error: 0.03160108072142446
# Epoch: 14001 Error: 0.03157156355061911
# Epoch: 15001 Error: 0.03154646599893938
# Epoch: 16001 Error: 0.031524867051133346
# Epoch: 17001 Error: 0.03150608377861384
# Epoch: 18001 Error: 0.0314895992498038
# Epoch: 19001 Error: 0.031475015065020616
# Epoch: 20001 Error: 0.0314620192759551
# Epoch: 21001 Error: 0.031450364172293716
# Epoch: 22001 Error: 0.03143985056698184
# Epoch: 23001 Error: 0.031430316466650995
# Epoch: 24001 Error: 0.03142162877592158
# Epoch: 25001 Error: 0.031413677104906494
# Epoch: 26001 Error: 0.03140636911200816
# Epoch: 27001 Error: 0.031399626932423354
# Epoch: 28001 Error: 0.03139338442254936
# Epoch: 29001 Error: 0.03138758499767462

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.plot(error)

# %%
network.params
# Out:
# array([ -5.57124796,  -5.53775799, -10.87166666,   2.10030162,
#          2.09918286, -10.86967727, -17.61832197,   4.76355688,
#          4.7615275 ])

# %%
network.activate([0,0])
# Out:
# array([0.01718103])

# %%
network.activate([0,1])
# Out:
# array([0.98485816])

# %%
network.activate([1,0])
# Out:
# array([0.98485726])

# %%
network.activate([1,1])
# Out:
# array([0.5003035])
